# %%
print("My name is Ranjana")
# Out:
# My name is Ranjana

# %%
a = 57
b = 90
c = 57*90
print(c)
# Out:
# 5130

# %%
x = 9
print(x**5)
# Out:
# 59049

# %%
print(8%2)
# Out:
# 0

# %%
print("My name is Ranjana Baniya \n I live in Imadol")
# Out:
# My name is Ranjana Baniya
#  I live in Imadol

# %%
list = [2,3,4,5,6,7,8]
print(len(list))
# Out:
# 7

# %%
list = [2,3,4,5,6,7,8]
print(type[list])
print(list[3])
# Out:
# type[[2, 3, 4, 5, 6, 7, 8]]
# 5

# %%
list = [2,3,4,5,6,7,8]
print(list[0])
# Out:
# 2

# %%
age = 20
if age >= 18:
    print("you are eligible to drive")
else: 
    print("You are not eligible to drive")
"end of loop"
# Out:
# you are eligible to drive
# 'end of loop'

# %%
a = 5 
b = 67.5
c = "Ranju"
d = "We are learning python"
print(a, b, c, d)
# Out:
# 5 67.5 Ranju We are learning python

# %%
first_name = "John"
last_name = "Sharma"
print("first_name + last_name")
# Out:
# first_name + last_name

# %%
first_name = "John"
last_name = "Sharma"
print(first_name + last_name)
# Out:
# JohnSharma

# %%
first_name = "John"
last_name = "Sharma"
print(first_name,last_name)
# Out:
# John Sharma

# %%
# If space is added between two string to give one output, it is concetation
first_name = "John"
last_name = "Sharma"
fullname = first_name + " " + last_name  
print(fullname)
# Out:
# John Sharma

# %%
x = 5
x = 10
print(x)
# Out:
# 10

# %%
info = {
    "Age" : 56,
    "Marks" : 90.5,
    "subjects" : ["maths","science", "english", "nepali"],
    "Name" : "sujan"
}
print(info)
print(type(info))
# Out:
# {'Age': 56, 'Marks': 90.5, 'subjects': ['maths', 'science', 'english', 'nepali'], 'Name': 'sujan'}
# <class 'dict'>

# %%
dict = {
   "Age" : 56,
    "Marks" : 90.5,
    "subjects" : ["maths","science", "english", "nepali"],
    "Name" : "sujan"
}
    
dict["Age"],dict["Marks"], dict["subjects"],["Name"]
# Out:
# (56, 90.5, ['maths', 'science', 'english', 'nepali'], ['Name'])

# %%
      #sets
#Sets in Python are unordered collections of unique elements.(so, index/ slices not worked)
# They are mutable, meaning you can add or remove items after creation, 
# but the elements within the set must be immutable(element cant be changed) 
# Sets are commonly used for membership testing, removing duplicates,
# and performing mathematical set operations.
#Creating Sets:
#Sets can be created using curly braket {} or the set() constructor. 

# Using curly braket
set1= {1, 2, 3}
print(set1)

set2 = {1, 2, 3, 4.0, 3,"Ankit",True}
print(set2)

set1 = {10, 56, 89, 70, True, "Prakrit"}
# set donot have no order,jun form ma insert garyo tehi form ma result aaudaina
print(set1)
print(type(set1))
# Out:
# {1, 2, 3}
# {1, 2, 3, 4.0, 'Ankit'}
# {True, 'Prakrit', 70, 56, 89, 10}
# <class 'set'>

# %%
#Set operations:

#issubset(other_set) or <=: Returns True if all elements of the set are in the other set.
#issuperset(other_set) or >=: Returns True if the set contains all elements of the other set.
#isdisjoint(other_set): Returns True if the set has no elements in common with the other set.

set1 = {1, 2, 3, 4}
set2 = {3, 4, 5, 6}
0
#union(other_set) or |: Returns a new set with all elements from both sets0
print(set1.union(set2)) #Output : {1, 2, 3, 4, 5, 6}

#intersection(other_set) or &: Returns a new set with elements common to both sets.
print(set1.intersection(set2)) # Output: {3, 4}    

#difference(other_set) or -: Returns a new set with elements in the first set but not the second.
print(set1.difference(set2)) # Output: {1, 2}

#symmetric_difference(other_set) or : Returns a new set with elements in either set, but not both.
print(set1.symmetric_difference(set2)) # Output: {1, 2, 5, 6}

#Frozensets:
#Python also offers frozenset, an immutable version of a set. 
# It does not allow adding or removing elements after creation. Frozensets are useful when you need to use sets as keys in dictionaries or as elements of other sets, as these require immutable objects.
# Out:
# {True, 99, 'Ram, 50', 10, 30}
# {1, 2, 3, 4, 5, 6}
# {3, 4}
# {1, 2}
# {1, 2, 5, 6}

# %%
# if empty set is created it will be dictionary
set1 = { }
print(set1)
print(type(set1))

set2 = set()    #  set()constructor should be used only to create empty set
print(type(set2))
# Out:
# {}
# <class 'dict'>
# <class 'set'>

# %%
#Basic Operations
#Adding elements:
#add(element): Adds a single element to the set.

set1 = {10, 30, True, "Ram, 50"}
set1.add(99)
print(set1)
# Out:
# {True, 99, 'Ram, 50', 10, 30}

# %%
#discard(element): Removes a specific element if it exists; does nothing if not found.
set1 = {10, 30, True, "Ram, 50"}
print("with the element that doesnot exist")

print(set1.discard(308))

print("with the element that exists in set1")
print(set1.discard(30))
# Out:
# with the element that doesnot exist
# None
# with the element that exists in set1
# None

# %%
#Removing elements:
#remove(element): Removes a specific element; raises an error if the element is not found.
set = {"Ram", "Shyam", "Rita", "Sita"}
set.remove("Shyam")
print(set)
# Out:
# {'Sita', 'Rita', 'Ram'}

# %%
#update(iterable): Adds multiple elements from an iterable (like a list or another set).
var = {"Ram", "Shyam", "Rita", "Sita"}
var.update(["ramu", 80])  # for update square bracket is used(to insert nultiple item)
print(var)
# Out:
# {'Rita', 'Ram', 'Sita', 'ramu', 80, 'Shyam'}

# %%
#pop(): Removes and returns an arbitrary element from the set.(remove random element)
collection = {"Ram", 90, "Shyam", 45.9,"Rita", "Sita" , True,"Sita"}
print("collection is", collection)
print(len(collection))

print(collection.pop())   # 1st time remove "True"
# it always remove one random element of set 
print(collection.pop())    # 2nd time remove "Sita"
# Out:
# collection is {True, 'Sita', 'Rita', 'Shyam', 90, 45.9, 'Ram'}
# 7
# True
# Sita

# %%
#Clear(): it clears the all element of set making it empty
collection = {"Ram", 90, "Shyam", 45.9,"Rita", "Sita" , True,"Sita"}
print(collection.clear())
# Out:
# None

# %%
#Membership testing:
#element in set: Returns True if the element is in the set, False otherwise.



#element not in set: Returns True if the element is not in the set, False otherwise.

# %%
#store following word meaning in a python dictionary:
# "table": "a piece of furniture", "a list of facts and figure"
# "cat": " a small animal",   
 
# Ans:
dict = {
    "cat": " a small animal",     # when two value is given 
    "table": ["a piece of furniture", "a list of facts and figure"] 
    
}

print(dict)
print(len(dict))
# Out:
# {'cat': ' a small animal', 'table': ['a piece of furniture', 'a list of facts and figure']}
# 2

# %%
#You are given a list of subjects for students. Assume one classroom is required for 1 subject.
#How many classrooms are needed by all students

# "python","java", "C++","python","javascript", "java", "python", "java","C++","c"
subjects= {"python","java", "C++","python","javascript", "java", "python", "java","C++","c" }
print(subjects)
print(len(subjects))
# Out:
# {'java', 'c', 'jajascript', 'python', 'C++'}
# 5

# %%
# WAP to enter marks of 3 subjects from the user and store them in a dictionary. 
# Start with an empty dictionary & add one by one. Use subjects names as key & marks as value

marks = {}   # start with empty dict
x = int(input("enter  mark of math:",)) # to input marks of 3 subject one by one
marks.update({"math":x})
y = int(input("enter mark of science:",))
marks.update({"science":y})
z = int(input("enter mark of english:",))
        
marks.update({ "english":z})
print(marks)
# Out:
# {'math': 45, 'science': 80, 'english': 90}

# %%
# Figure out a way to store 9 & 9.0 as separate values in the set
set1 = { 9, "9.0"}
print(set1)


set2 = { 9, 9.0}  # As 9 and 9.0 is taken as same value we use 9.0 as string value
print(set2)
# Out:
# {9, '9.0'}
# {9}

# %%
# Figure out a way to store 9 & 9.0 as separate values in the set using built-in data types
values = {
    ("int", 9),
    ("float", 9.0)
}
print(values)        # dictionary ma pair banayera tuple vitra rakhne
# Out:
# {('float', 9.0), ('int', 9)}

# %%
#In Python, functions can accept different types of arguments, providing flexibility in how 
# they are called and used. 
# The main types of arguments are:
      #Positional Arguments: These are the most common type and are passed to the function
# based on their order or position in the function call. 
#The number of arguments must match the number of parameters defined in the function.

def calc_sum(a, b):
        sum = a+b
        return sum
    
s= calc_sum(25, 30)
print(s)
# Out:
# 55

# %%
list1 = [[12,34,54],[35,56,23],[45,24,21]] # multiply by 2  and print list in  the same form

# Answer
result =[]  # To create new list and store result
for sublist in list1:  # To iterate through each sublist
# Multiply each element by 2 using a loop
   new_sublist = []
   for item in sublist:
       new_sublist.append(item*2)
   result.append(new_sublist)

print(result) # for printing final result
# Out:
# [[24, 68, 108], [70, 112, 46], [90, 48, 42]]

# %%
# list1 = [[12,34,54],[35,56,23],[45,24,21]] # multiply by 2  and print list in  the row form

# %%
list1 = [[12,34,54],[35,56,23],[45,24,21]]
result = []
for sublist in list1:   # This is loop under loop or nested loop
    new_sublist = []
    for item in sublist:
        new_sublist.append(item*2)
    
    result.append(new_sublist)
    
for row in result:
   print(result)
    

print("end of loop")
for row in result:
    print(row)
# Out:
# [[24, 68, 108], [70, 112, 46], [90, 48, 42]]
# [[24, 68, 108], [70, 112, 46], [90, 48, 42]]
# [[24, 68, 108], [70, 112, 46], [90, 48, 42]]
# end of loop
# [24, 68, 108]
# [70, 112, 46]
# [90, 48, 42]
