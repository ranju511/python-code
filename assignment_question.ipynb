# %% [markdown]
# Suman Bhandari
#
# # Python Basics Assignment
#
# ## Topics Covered:
# - Syntax and Semantics
# - Variables and Data Types
# - Basic Operators (Arithmetic, Comparison, Logical)

# %% [markdown]
# ## 1. Syntax and Semantics
#
# **Question 1:** Write a Python program to print "Hello, World!".

# %%
str1 = "Hello , World!"
print(str1)
print("Hello, World!")
# Out:
# Hello , World!
# Hello, World!

# %% [markdown]
# Question 2:Write a Python program that takes a user input and print it.

# %%
num = int(input("enter a number:"))
print("The entered number is:",num)
# Out:
# The entered number is: 45

# %% [markdown]
# Question 3: Write a Python program to check if a number is positive, negative, or zero.

# %%
num = int(input("enter a number"))
if num > 0:
    print("The num is positive")
elif num ==0:
    print("The num is zero")
else:
    print("The num is negative")
# Out:
# The num is positive

# %% [markdown]
# **Question 4:** Write a Python program to find the largest of three numbers.

# %%
num1 = int(input("enter first number"))
num2 = int(input("enter second number"))
num3 = int(input("enter third number"))
if(num1>num2 and num1>num3):
    print("The largest number is num1:",num1)
elif(num2>num1 and num2>num3):
    print("The largest number is num2:",num2)
else:
     print("The largest number is num3:",num3)
# Out:
# The largest number is num2: 89

# %% [markdown]
# **Question 5:** Write a Python program to calculate the factorial of a number.

# %%
n= 8
fact = 1
for i in range(1,n+1):
    fact *= i
print("The factorial of 8 number is:",fact)
# Out:
# The factorial of 8 number is: 40320

# %% [markdown]
# ## 2. Variables and Data Types
#
# **Question 6:** Create variables of different data types: integer, float, string, and boolean. Print their values and types.

# %%
a = 5
b = 10.2
c = "hello"
d = True

print(a)
print(b)
print("c")
print(d)

print(type(a))
print(type(b))
print(type(c))
print(type(d))
# Out:
# 5
# 10.2
# c
# True
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %% [markdown]
# **Question 7:** Write a Python program to swap the values of two variables.

# %%
a = 50
b = 60
# For exchanging the value of a and b
a = 60
b = 50
print("he value of a after swapping is:",a)
print("The value of b after swapping is:",b)
# Out:
# he value of a after swapping is: 60
# The value of b after swapping is: 50

# %% [markdown]
# **Question 8: Write a Python program to convert Celsius to Fahrenheit.

# %%
celsius = 45  
fahrenheit = (celsius*1.8)+32
print("The result of conversion of celsius to fahrenheit is:",fahrenheit)
# Out:
# The result of conversion of celsius to fahrenheit is: 113.0

# %% [markdown]
# **Question 9:** Write a Python program to concatenate two strings.

# %%
str1 = "Ranjana"
str2 = "Baniya"
final_str = "Ranjana"+ " " + "Baniya"
print(final_str)
# or
print(str1 , str2)
# Out:
# Ranjana Baniya
# Ranjana Baniya

# %% [markdown]
# **Question 10:** Write a Python program to check if a variable is of a specific data type.

# %% [markdown]
# ## 3. Basic Operators (Arithmetic, Comparison, Logical)
#
# **Question 11:** Write a Python program to perform arithmetic operations: addition, subtraction, multiplication, and division.

# %%
x = 78
y = 56
sum = x+y
# Addition
print("The result of sum is:", sum)
 
#Subtraction
subs = x-y
print("he result of substraction is :", subs)

# Multiplication
mul= x*y
print("The result of multiplication is:",mul)

#Division 
Div = x/y
print("he result of division is:",Div)
# Out:
# The result of sum is: 134
# he result of substraction is : 22
# The result of multiplication is: 4368
# he result of division is: 1.3928571428571428

# %% [markdown]
# **Question 12:** Write a Python program to demonstrate comparison operators: equal to, not equal to, greater than, less than.

# %%
a = 70
b = 80
c = 90
"Equal to operator"
print(a == b)
print(b == c)

"not equal to"
print(a!=b)
print(b!=c)

"greater than"
print(a>b)
print(c>b)
# Out:
# False
# False
# True
# True
# False
# True

# %% [markdown]
# **Question 13:** Write a Python program to demonstrate logical operators: and, or, not.

# %%
x = True
y = False
print("Using and logical operator")
print(x and y)
print(y and x)
print(True and False)
print(False and True)

print("Using or logical operator")
print(x or y)
print(y or x)
print(True or False)
print(False or True)
print("using Not equal to operator")
print(x!=b)
print(y!=x)
# Out:
# Using and logical operator
# False
# False
# False
# False
# Using or logical operator
# True
# True
# True
# True
# using Not equal to operator
# True
# True

# %% [markdown]
# **Question 14:** Write a Python program to calculate the square of a number.

# %%
x = 8
square = x*x
print(square)
# Out:
# 64

# %% [markdown]
# **Question 15:** Write a Python program to check if a number is even or odd.

# %%
num = int(input("enter a number"))
if (num%2==0):
    print("The entered number is even:",num)
else:
    print("The entered number is odd:",num)
# Out:
# The entered number is odd: 45

# %% [markdown]
# **Question 16:** Write a Python program to find the sum of the first n natural numbers.

# %%
n = 100

sum = n*(n+1)/2

print("The sum of first 100 natural number is:",sum)

# using function
def sum_numbers(int):
    num = 100, 99, 98,...,1
    sum= n*(n+1)/2
    print("The sum of first 100 natural number is:",sum)
    return sum
sum = sum_numbers(100)
# Out:
# The sum of first 100 natural number is: 5050.0
# The sum of first 100 natural number is: 5050.0

# %% [markdown]
# **Question 17:** Write a Python program to check if a year is a leap year.

# %%
year = 2024
if(year%4==0):
    print("leap year")
    
else:
    print("not a leap year")
# Out:
# leap year

# %% [markdown]
# **Question 18:** Write a Python program to reverse a string.

# %%
str = "Ranjana Baniya"
print(str[::-1])
#or
print(str[-1:-14:-1])
# Out:
# ayinaB anajnaR
# ayinaB anajna

# %% [markdown]
# **Question 19:** Write a Python program to check if a string is a palindrome.

# %%
str = input("enter a string:",)

if str[::-1]==str[::1]:
    print("The entered string is palindrome:",str)
else:
    print("The entered string is not palindrome:",str)
# Out:
# The entered string is palindrome: madam

# %%
str = input("enter a string:",)

if str[::-1]==str[::1]:
    print("The entered string is palindrome:",str)
else:
    print("The entered string is not palindrome:",str)
# Out:
# The entered string is not palindrome: teacher

# %%
# To check string is palindrome or not
str1 = input("enter a string:",)
if str1[::-1]==str1[::1]:
    print("The entered string is palindrome:",str1)
else:
    print("The entered string is not palindrome:",str1)
# Out:
# The entered string is palindrome: madam

# %% [markdown]
# **Question 20:** Write a Python program to sort a list of numbers in ascending order.

# %%
list = [3, 9, 120, 30, 70, 90, 85, 76]
list.sort()
print(list)
# Out:
# [3, 9, 30, 70, 76, 85, 90, 120]
